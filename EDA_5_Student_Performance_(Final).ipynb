# %% [markdown]
# # Student Performance
#
# The dataset is related to student performance and attributes in secondary education. Here's a general introduction based on the columns present in the DataFrame:
#
# This dataset contains information about students in secondary education, including demographic details, family background, educational support, lifestyle choices, and academic performance. Each row represents a unique student, and the columns provide various attributes and characteristics associated with them.

# %% [markdown]
# ## Dataset contains following columns:
#
# * school: School attended by the student.
# * sex: Student's gender (male or female).
# * age: Student's age.
# * address: Type of address of the student (urban or rural).
# * famsize: Family size (binary categorization: "LE3" - less or equal to 3 or "GT3" - greater than 3).
# * Pstatus: Parent's cohabitation status (living together or apart).
# * Medu: Mother's education level (0 to 4, representing none to higher education).
# * Fedu: Father's education level (0 to 4, representing none to higher education).
# * Mjob: Mother's occupation.
# * Fjob: Father's occupation.
# * reason: Reason for choosing the school.
# * guardian: Student's guardian.
# * traveltime: Travel time to school.
# * studytime: Weekly study time (hours).
# * failures: Number of past class failures.
# * schoolsup: Extra educational support at school (yes or no).
# * famsup: Family educational support (yes or no).
# * paid: Extra paid classes within the course subject (yes or no).
# * activities: Extra-curricular activities (yes or no).
# * nursery: Attended nursery school (yes or no).
# * higher: Wants to take higher education (yes or no).
# * internet: Internet access at home (yes or no).
# * romantic: In a romantic relationship (yes or no).
# * famrel: Quality of family relationships (from 1 - very bad to 5 - excellent).
# * freetime: Free time after school (from 1 - very low to 5 - very high).
# * goout: Going out with friends (from 1 - very low to 5 - very high).
# * Dalc: Workday alcohol consumption (from 1 - very low to 5 - very high).
# * Walc: Weekend alcohol consumption (from 1 - very low to 5 - very high).
# * health: Current health status (from 1 - very bad to 5 - very good).
# * absences: Number of school absences.
# * G1: First period grade (from 0 to 20).
# * G2: Second period grade (from 0 to 20).
# * G3: Final grade (from 0 to 20).

# %%
#Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

import warnings
warnings.filterwarnings('ignore')

# %%
#Read CSV File using Pandas
df = pd.read_csv('/content/student-por.csv')

# %% [markdown]
# #**Profile of Data (Basic Analysis of Data)**

# %%
df.shape
# Out:
# (649, 33)

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
#Statistic Data
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
#Check null values
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# **Insight**-there are no null values in the dataset

# %% [markdown]
# #**Univariate Analysis**

# %%
#Create a Countplot for School
plt.figure(figsize = (8,5))
sns.countplot(x = 'school',data = df, palette = 'husl')
plt.title('Distribution of School')
plt.xlabel('School')
plt.ylabel('Count')
plt.show()

# %%
df['school'].value_counts()
# Out:
# school
# GP    423
# MS    226
# Name: count, dtype: int64

# %% [markdown]
# **Insight**-GP has larger no of stiudents

# %%
#Create a Histplot for Age
sns.histplot(df['age'], bins = 8, kde = True, color = 'blue')
plt.title('Histplot for Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Insight**-Most common age group 15-16 and Right skewed distribution.

# %%
#Create a Countplot for Address
sns.countplot(x = 'address',data = df, palette = 'dark')
plt.title('Distribution of Address')
plt.xlabel('Address')
plt.ylabel('Count')
plt.show()

# %%
df['address'].value_counts()
# Out:
# address
# U    452
# R    197
# Name: count, dtype: int64

# %% [markdown]
# **Insight**-There are many students from urban areas

# %%
#Create a Pie Chart for Reason
reason_counts = df['reason'].value_counts()
plt.pie(reason_counts, labels = reason_counts.index, autopct = '%1.1f%%', )
plt.title('Piechart Distribution for Reason')
plt.show()

# %% [markdown]
# **Insight**-common reason for joining school would be course

# %%
#Create a Pie Chart for Activities
act = df['activities'].value_counts()
plt.pie(act, labels = act.index, autopct = '%1.1f%%', )
plt.title('Piechart Distribution for Activities')
plt.show()

# %% [markdown]
# Insight-48.5% students are participating in activities

# %%
#Weekly Alcohol Consumption
df['Walc'].value_counts()
# Out:
# Walc
# 1    247
# 2    150
# 3    120
# 4     87
# 5     45
# Name: count, dtype: int64

# %% [markdown]
# **Insight**-45 students have regular weekend alcohal consumption

# %%
#Daily Alcohol Consumption
df['Dalc'].value_counts()
# Out:
# Dalc
# 1    451
# 2    121
# 3     43
# 5     17
# 4     17
# Name: count, dtype: int64

# %% [markdown]
# **Insight**-17 students have regular daily alcohal consumption

# %% [markdown]
# #**Bivariate Analysis**

# %%
#Create a Countplot for Mother and Father Education
plt.figure(figsize = (12,6))

plt.subplot(1,2,1)
sns.countplot(x = 'Medu', data = df, palette = 'Set2')
plt.title('Mother Education Level Distribution')
plt.xlabel('Mother Education Level')
plt.ylabel('Count')

plt.subplot(1,2,2)
sns.countplot(x = 'Fedu', data = df, palette = 'Set3')
plt.title('Father Education Level Distribution')
plt.xlabel('Father Education Level')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# **Insight**-Both mothers and fathers have a similar distribution of education levels, with level 2 being the most common. There is a higher count of level 4 education for mothers compared to fathers.

# %%
#Create a Barplot for study time G1.
sns.barplot(x = 'studytime', y = 'G1', data = df, palette = 'Set1')
plt.title('Distribution of Study Time in G1')
plt.xlabel('Study Time')
plt.ylabel('Count')
plt.show()

# %%
#Create a Barplot for study time G2.
sns.barplot(x = 'studytime', y = 'G2', data = df, palette = 'Set2')
plt.title('Distribution of Study Time in G2')
plt.xlabel('Study Time')
plt.ylabel('Count')
plt.show()

# %%
#Create a Barplot for study time G3.
sns.barplot(x = 'studytime', y = 'G3', data = df, palette = 'Set3')
plt.title('Distribution of Study Time in G3')
plt.xlabel('Study Time')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Insight For Study Time in G1, G2 and G3**- Students tend to study more, as higher study time categories (3 and 4) are more common. The difference between study time categories is relatively small, but there is a clear trend that fewer students fall into the lowest study time category (1).

# %%
#Create a Barplot for Internet usage time in G1.
sns.barplot(x = 'internet', y = 'G1', data = df, palette = 'Set1')
plt.title('Distribution of Internet in G1')
plt.xlabel('Internet')
plt.ylabel('Count')
plt.show()

# %%
#Create a Barplot for Internet usage time in G2.
sns.barplot(x = 'internet', y = 'G2', data = df, palette = 'Set2')
plt.title('Distribution of Internet in G2')
plt.xlabel('Internet')
plt.ylabel('Count')
plt.show()

# %%
#Create a Barplot for Internet usage time in G3.
sns.barplot(x = 'internet', y = 'G3', data = df, palette = 'Set3')
plt.title('Distribution of Internet in G3')
plt.xlabel('Internet')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Insight For Internet usage in G1, G2 and G3**-The majority of students have internet access, although the difference between the two groups is minimal. This suggests that internet access is fairly common among the students in G1.

# %% [markdown]
# #**Multivariate Analysis**

# %%
#Create a Barplot for Sex, G3 and Hue-Address
sns.barplot(x = 'sex', y = 'G3', hue = 'address', data = df, palette = 'husl')
plt.title('Barplot for Male Vs Female G3 Marks')
plt.xlabel('Sex')
plt.ylabel('G3 Marks')
plt.show()

# %% [markdown]
# **Insight**-This analysis suggests that urban students generally have better academic performance (G3 marks) than rural students, regardless of gender. This could be due to a variety of factors such as access to resources, quality of education, and socioeconomic factors.

# %%
#Analysis of Numerical Columns using Boxplot
num_cols = ['age', 'traveltime', 'studytime', 'absences', 'G1', 'G2', 'G3']
plt.figure(figsize = (10,6))
sns.boxplot(data = df[num_cols], palette = 'dark')
plt.title('Boxplot for Numerical Columns')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Insight**-The data shows that age, travel time, and study time are relatively consistent among students, while absences and grades have more variability and outliers. Absences, in particular, stand out with a wide range and many outliers, suggesting that absenteeism is an issue worth further investigation, possibly linking it to academic performance (grades).

# %%
#Create a heatmap using numeric columns
corr = df.corr(numeric_only = True)
plt.figure(figsize = (12,6))
sns.heatmap(corr, cmap = 'viridis', annot = True, fmt = '.2f')
plt.title('Heatmap for Numerical Data')
plt.show()

# %% [markdown]
# **Insight**-Medu (Mother's education) and Fedu (Father's education) have a high positive correlation (0.65). Studytime also shows a small positive correlation with grades (G1, G2, G3), though it's not as strong as other factors.

# %% [markdown]
# #**Outlier Detection and Treatment**

# %%
#Make a deep copy of df and drop the G1, G2 and G3.
student_grades_df = df.copy()
student_grades_df = student_grades_df.drop(['G1', 'G2', 'G3'], axis = 1)

# %%
#Make a function for outlier detection using Statistic basic understanding.
def detect_outlier (columns):
  outlier_indices = []
  for column in columns:
    Q1 = student_grades_df[column].quantile(0.25)
    Q3 = student_grades_df[column].quantile(0.75)
    IQR = Q3 - Q1
    #mask is boolean condition
    mask = (student_grades_df[column] >= (Q1 - 1.5*IQR)) & (student_grades_df[column] >= (Q3  + 1.5*IQR))

    mask = mask.to_numpy() #bool value to numpy array

    #find the indices of values that do not satisfy the mask condition that will be outlier
    false_indices = np.argwhere(~mask)
    outlier_indices.append(false_indices)
  return np.unique(np.concatenate(outlier_indices).ravel())

# %%
num_cols = ['age' , 'absences']
outlier_indices = detect_outlier(num_cols)

# %%
#Data Split-Assign x and y.
x,y = student_grades_df.iloc[:, :-1], student_grades_df.iloc[:, -1]

# %%
x.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   nursery higher  internet  romantic  famrel freetime goout Dalc Walc health
# 0     yes    yes        no        no       4        3     4    1    1      3
# 1      no    yes       yes        no       5        3     3    1    1      3
# 2     yes    yes       yes        no       4        3     2    2    3      3
# 3     yes    yes       yes       yes       3        2     2    1    1      5
# 4     yes    yes        no        no       4        3     2    1    2      5
#
# [5 rows x 29 columns]

# %%
y.head()
# Out:
# 0    4
# 1    2
# 2    6
# 3    0
# 4    0
# Name: absences, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
#Use Train Test Split for Spliting the data for ML model.
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.25, random_state = 1)

# %%
x_train.shape
# Out:
# (486, 29)

# %%
x_test.shape
# Out:
# (163, 29)

# %% [markdown]
# Now train the data for ML Models
